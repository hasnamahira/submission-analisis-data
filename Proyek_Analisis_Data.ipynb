# %% [markdown]
# # Proyek Analisis Data: Bike Sharing Dataset
# - **Nama:** Hasna Mahira Mufidati
# - **Email:** hasnamahiramufidati2005@mail.ugm.ac.id
# - **ID Dicoding:** CDCC008D6X2723

# %% [markdown]
# ## Dataset

# %%
readme = "/content/Readme.txt"
with open(readme, "r") as file:
    isi_file = file.read()
    print(isi_file)
# Out:
# ...
# Bike Sharing Dataset
# ...
#
# Hadi Fanaee-T
#
# Laboratory of Artificial Intelligence and Decision Support (LIAAD), University of Porto
# INESC Porto, Campus da FEUP
# Rua Dr. Roberto Frias, 378
# 4200 - 465 Porto, Portugal
#
#
# ...
# Background
# ...
#
# Bike sharing systems are new generation of traditional bike rentals where whole process from membership, rental and return
# back has become automatic. Through these systems, user is able to easily rent a bike from a particular position and return
# back at another position. Currently, there are about over 500 bike-sharing programs around the world which is composed of
# over 500 thousands bicycles. Today, there exists great interest in these systems due to their important role in traffic,
# environmental and health issues.
#
# Apart from interesting real world applications of bike sharing systems, the characteristics of data being generated by
# ...

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# **SMART Question** adalah sebuah framework untuk merumuskan pertanyaan secara terstruktur agar memeperoleh informasi yang mendalam.
#
# * **Spesific (Spesifik)**
#   * Pertanyaan harus jelas, fokus pada sebuah topik tertentu, dan tidak bermakna ganda. Hindari pertanyaan yang terlalu luas.
#     * Salah: Bagaimana cara meningkatkan penjualan?
#     * Benar: Faktor apa saja yang memengaruhi penurunan penjualan produk kategori elektronik di wilayah Jakarta selama kuartal terakhir?
# * **Measurable (Terukur)**
#   * Pertanyaan harus bisa dijawab dengan angka atau matrix yang konkret, harus tahu apa yang akan dihitung.
#     * Salah: Apakah pelanggan senang dengan layanan kita?
#     * Benar: Berapa skor rata-rata Customer Satisfaction untuk layanan purna jual bulan ini dibandingkan bulan lalu?
# * **Action-Oriented (Berorientasi Aksi)**
#   * Hasil dari pertanyaan harus bisa memberikan arahan untuk melakukan tindakan nyata. Jika pertanyaan terjawab, stakeholder harus tahu apa langkah selanjutnya.
#     * Salah: Mengapa orang suka berbelanja?
#     * Benar: Fitur apa pada aplikasi yang paling sering digunakan sebelum pengguna memutuskan untuk melakukan checkout?
# * **Relevant (Relevan)**
#   * Hasil dari pertanyaan harus sejalan dengan tujuan utama bisnis atau masalah yang sedang dihadapi.
#     * Salah: Menanyakan tentang stok gudang saat masalah utamanya adalah efektivitas kampanye media sosial.
#     * Benar: Apakah kampanye iklan di Instagram memberikan Return on Ad Spend (ROAS) yang lebih tinggi dibandingkan iklan di TikTok?
# * **Time-bound (Terikat Waktu)**
#   * Pertanyaan harus ada batasan waktu yang jelas agar analisis memiliki konteks yang tepat.
#     * Salah: Berapa banyak pengguna baru kita?
#     * Benar: Berapa tingkat pertumbuhan pengguna baru secara bulanan (Month-over-Month) sepanjang tahun 2025?

# %% [markdown]
# **Contoh pertanyaan bisnis yang memenuhi seluruh elemen SMART**
#
# ***"Faktor apa saja yang memengaruhi penurunan conversion rate pada pengguna aplikasi Android di wilayah Jabodetabek sebesar 5% selama periode Flash Sale Maret 2026?"***
#
# Keterangan:
#
# - **Specific**: Fokus pada "penurunan conversion rate" untuk "aplikasi Android" di "Jabodetabek". Bukan sekadar penjualan turun.
# - **Measurable**: Ada angka konkret yang ingin dianalisis, yaitu penurunan sebesar "5%".
# - **Action-Oriented**: Dengan mengetahui faktor penyebabnya misalnya bug pada versi Android tertentu atau kendala logistik di Jabodetabek, tim bisa langsung melakukan perbaikan teknis atau operasional.
# - **Relevant**: Penurunan konversi saat Flash Sale adalah masalah kritis bagi bisnis retail/e-commerce.
# - **Time-bound**: Dibatasi pada periode spesifik "Flash Sale Maret 2026".

# %% [markdown]
# - **Pertanyaan 1:** Seberapa besar pengaruh variabel terhadap jumlah penyewaan sepeda selama tahun 2012
# - **Pertanyaan 2:** Berapa rata-rata jumlah penyewaan sepeda pada hari kerja dibandingkan akhir pekan dalam setiap musim selama periode 2011-2012, dan bagaimana perbedaannya?
# - **Pertanyaan 3:** Pada bulan apa tingkat penyewaan sepeda tertinggi di tahun 2011?
# - **Pertanyaan 4:** Pada jam berapa tingkat penyewaan sepeda tertinggi terjadi setiap bulan di tahun 2011 dan 2012?
# - **Pertanyaan 5:** Berapa proporsi pengguna casual dibandingkan registered dalam total penyewaan sepeda setiap musim selama tahun 2011-2012?
# - **Pertanyaan 6:** Seberapa besar penurunan rata-rata jumlah penyewaan sepeda pada kondisi cuaca buruk (weathersit = 3 dan 4) dibandingkan cuaca cerah (weathersit = 1) dalam periode 2011-2012?

# %% [markdown]
# ## Import Semua Packages/Library yang Digunakan

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %% [markdown]
# #### Load df day & hour

# %%
df_day = pd.read_csv("/content/day.csv")
df_day.head()
# Out:
#    instant    dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  1/1/2011       1   0     1        0        6           0
# 1        2  1/2/2011       1   0     1        0        0           0
# 2        3  1/3/2011       1   0     1        0        1           1
# 3        4  1/4/2011       1   0     1        0        2           1
# 4        5  1/5/2011       1   0     1        0        3           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# 1           2  0.363478  0.353739  0.696087   0.248539     131         670
# 2           1  0.196364  0.189405  0.437273   0.248309     120        1229
# 3           1  0.200000  0.212122  0.590435   0.160296     108        1454
# 4           1  0.226957  0.229270  0.436957   0.186900      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %%
df_hour = pd.read_csv("/content/hour.csv")
df_hour.head()
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1   0        0        6           0
# 1        2  2011-01-01       1   0     1   1        0        6           0
# 2        3  2011-01-01       1   0     1   2        0        6           0
# 3        4  2011-01-01       1   0     1   3        0        6           0
# 4        5  2011-01-01       1   0     1   4        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0           1  0.24  0.2879  0.81        0.0       3          13   16
# 1           1  0.22  0.2727  0.80        0.0       8          32   40
# 2           1  0.22  0.2727  0.80        0.0       5          27   32
# 3           1  0.24  0.2879  0.75        0.0       3          10   13
# 4           1  0.24  0.2879  0.75        0.0       0           1    1

# %% [markdown]
# **Insight:**
# - Data terdiri dari dua granularitas waktu, yaitu harian (day.csv) dan per jam (hour.csv). Hal ini memungkinkan analisis pola jangka panjang (tren musiman) sekaligus pola intraday (jam sibuk vs tidak).
# - Data time-series yang konsisten cocok untuk pemodelan forecasting, seperti regresi time series atau LSTM.

# %% [markdown]
# ### Assessing Data

# %% [markdown]
# **Steps to Take:**
# - Pengecekan struktur data
# - Pengecekan missing value
# - Pengecekan duplikasi data
# - Validasi konsistensi data

# %% [markdown]
# #### Identifying structure problem

# %%
df_day.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     731 non-null    int64
#  1   dteday      731 non-null    object
#  2   season      731 non-null    int64
#  3   yr          731 non-null    int64
#  4   mnth        731 non-null    int64
#  5   holiday     731 non-null    int64
#  6   weekday     731 non-null    int64
#  7   workingday  731 non-null    int64
#  8   weathersit  731 non-null    int64
#  9   temp        731 non-null    float64
#  10  atemp       731 non-null    float64
#  11  hum         731 non-null    float64
#  12  windspeed   731 non-null    float64
#  13  casual      731 non-null    int64
#  14  registered  731 non-null    int64
#  15  cnt         731 non-null    int64
# dtypes: float64(4), int64(11), object(1)
# memory usage: 91.5+ KB

# %% [markdown]
# **Insight:**
# - Data df_day memiliki 16 variabel dengan masing-masing berjumlah 731 nilai non-null.
# - Skala data pada variabel dteday perlu diubah menjadi datetime.

# %%
df_hour.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17379 entries, 0 to 17378
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     17379 non-null  int64
#  1   dteday      17379 non-null  object
#  2   season      17379 non-null  int64
#  3   yr          17379 non-null  int64
#  4   mnth        17379 non-null  int64
#  5   hr          17379 non-null  int64
#  6   holiday     17379 non-null  int64
#  7   weekday     17379 non-null  int64
#  8   workingday  17379 non-null  int64
#  9   weathersit  17379 non-null  int64
#  10  temp        17379 non-null  float64
#  11  atemp       17379 non-null  float64
#  12  hum         17379 non-null  float64
#  13  windspeed   17379 non-null  float64
#  14  casual      17379 non-null  int64
#  15  registered  17379 non-null  int64
#  16  cnt         17379 non-null  int64
# dtypes: float64(4), int64(12), object(1)
# memory usage: 2.3+ MB

# %% [markdown]
# **Insight:**
# - Data df_hour memiliki 17 variabel dengan masing-masing berjumlah 17379 nilai non-null.
# - Skala data pada variabel dteday perlu diubah menjadi datetime.

# %% [markdown]
# #### Identifying missing value

# %%
df_day.isna().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
df_hour.isna().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %% [markdown]
# **Insight:**
# - Tidak terdapat missing value pada kedua data

# %% [markdown]
# #### Identifying duplicate data

# %%
df_day.duplicated().sum()
# Out:
# np.int64(0)

# %%
df_hour.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# **Insight:**
# - Tidak terdapat duplikasi data pada kedua data

# %% [markdown]
# #### Identifying inconsistency data

# %%
df_day["cnt"].equals(df_day["casual"] + df_day["registered"])
# Out:
# True

# %%
df_hour["cnt"].equals(df_hour["casual"] + df_hour["registered"])
# Out:
# True

# %% [markdown]
# **Insight:**
# - Data sudah konsisten dengan pembuktian cnt = casual + registered

# %% [markdown]
# #### Identifying descriptive statistic

# %%
df_day.describe(include="all")
# Out:
#            instant      dteday      season          yr        mnth  \
# count   731.000000         731  731.000000  731.000000  731.000000
# unique         NaN         731         NaN         NaN         NaN
# top            NaN  12/31/2012         NaN         NaN         NaN
# freq           NaN           1         NaN         NaN         NaN
# mean    366.000000         NaN    2.496580    0.500684    6.519836
# std     211.165812         NaN    1.110807    0.500342    3.451913
# min       1.000000         NaN    1.000000    0.000000    1.000000
# 25%     183.500000         NaN    2.000000    0.000000    4.000000
# 50%     366.000000         NaN    3.000000    1.000000    7.000000
# 75%     548.500000         NaN    3.000000    1.000000   10.000000
# max     731.000000         NaN    4.000000    1.000000   12.000000
#
#            holiday     weekday  workingday  weathersit        temp  \
# count   731.000000  731.000000  731.000000  731.000000  731.000000
# ...

# %%
df_hour.describe(include="all")
# Out:
#            instant      dteday        season            yr          mnth  \
# count   17379.0000       17379  17379.000000  17379.000000  17379.000000
# unique         NaN         731           NaN           NaN           NaN
# top            NaN  2012-12-31           NaN           NaN           NaN
# freq           NaN          24           NaN           NaN           NaN
# mean     8690.0000         NaN      2.501640      0.502561      6.537775
# std      5017.0295         NaN      1.106918      0.500008      3.438776
# min         1.0000         NaN      1.000000      0.000000      1.000000
# 25%      4345.5000         NaN      2.000000      0.000000      4.000000
# 50%      8690.0000         NaN      3.000000      1.000000      7.000000
# 75%     13034.5000         NaN      3.000000      1.000000     10.000000
# max     17379.0000         NaN      4.000000      1.000000     12.000000
#
#                   hr       holiday       weekday    workingday    weathersit  \
# ...

# %% [markdown]
# **Insight:**
# - Variabel season, mnth, hr, weekday, dan weathersit merupakan variabel kategorikal
# - Variabel yr, holiday, dan workingday merupakan variabel biner
# - Nilai variabel temp, atemp, hum, dan windspeed tidak sesuai dengan kenyataan karena proses normalisasi sehingga perlu dilakukan denormalisasi.

# %% [markdown]
# ### Cleaning Data

# %% [markdown]
# #### Fixing time scale problem

# %%
df_day["dteday"] = pd.to_datetime(df_day["dteday"])

# %%
df_day.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     731 non-null    int64
#  1   dteday      731 non-null    datetime64[ns]
#  2   season      731 non-null    int64
#  3   yr          731 non-null    int64
#  4   mnth        731 non-null    int64
#  5   holiday     731 non-null    int64
#  6   weekday     731 non-null    int64
#  7   workingday  731 non-null    int64
#  8   weathersit  731 non-null    int64
#  9   temp        731 non-null    float64
#  10  atemp       731 non-null    float64
#  11  hum         731 non-null    float64
#  12  windspeed   731 non-null    float64
#  13  casual      731 non-null    int64
#  14  registered  731 non-null    int64
#  15  cnt         731 non-null    int64
# dtypes: datetime64[ns](1), float64(4), int64(11)
# memory usage: 91.5 KB

# %%
df_hour["dteday"] = pd.to_datetime(df_hour["dteday"])

# %%
df_hour.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17379 entries, 0 to 17378
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     17379 non-null  int64
#  1   dteday      17379 non-null  datetime64[ns]
#  2   season      17379 non-null  int64
#  3   yr          17379 non-null  int64
#  4   mnth        17379 non-null  int64
#  5   hr          17379 non-null  int64
#  6   holiday     17379 non-null  int64
#  7   weekday     17379 non-null  int64
#  8   workingday  17379 non-null  int64
#  9   weathersit  17379 non-null  int64
#  10  temp        17379 non-null  float64
#  11  atemp       17379 non-null  float64
#  12  hum         17379 non-null  float64
#  13  windspeed   17379 non-null  float64
#  14  casual      17379 non-null  int64
#  15  registered  17379 non-null  int64
#  16  cnt         17379 non-null  int64
# dtypes: datetime64[ns](1), float64(4), int64(12)
# memory usage: 2.3 MB

# %% [markdown]
# **Insight:**
# - Skala variabel dteday sudah dalam bentuk datetime

# %% [markdown]
# #### Denormalisasi

# %%
df_day["temp"] = df_day["temp"].multiply(41)
df_day["atemp"] = df_day["atemp"].multiply(50)
df_day["hum"] = df_day["hum"].multiply(100)
df_day["windspeed"] = df_day["windspeed"].multiply(67)

# %%
df_hour["temp"] = df_hour["temp"].multiply(41)
df_hour["atemp"] = df_hour["atemp"].multiply(50)
df_hour["hum"] = df_hour["hum"].multiply(100)
df_hour["windspeed"] = df_hour["windspeed"].multiply(67)

# %% [markdown]
# **Insight:**
# - Variabel temp, atemp, hum, dan windspeed sudah dilakukan denormalisasi sehingga dapat digunakan untuk analisis berikutnya.

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Explore Distribusi Variabel & Pengecekan Outlier

# %% [markdown]
# #### Data day

# %%
data = df_day[['temp', 'atemp', 'hum', 'windspeed']]
plt.figure()
plt.boxplot(data.values, labels=data.columns)
plt.title('Boxplot Variabel Cuaca')
plt.xlabel('Variabel')
plt.ylabel('Nilai')
plt.show()
# Out:
# /tmp/ipykernel_787/784924428.py:3: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(data.values, labels=data.columns)

# %%
# Mapping label
df_day.replace({
    "season": {1: "Springer", 2: "Summer", 3: "Fall", 4: "Winter"},
    "yr": {0: 2011, 1: 2012},
    "mnth": {
        1: "Jan", 2: "Feb", 3: "Mar", 4: "Apr",
        5: "May", 6: "Jun", 7: "Jul", 8: "Aug",
        9: "Sep", 10: "Oct", 11: "Nov", 12: "Dec"
    },
    "holiday": {0: "Not Holiday", 1: "Holiday"},
    "workingday": {0: "Holiday", 1: "Working Day"},
    "weekday": {
        0: "Sunday", 1: "Monday", 2: "Tuesday",
        3: "Wednesday", 4: "Thursday", 5: "Friday", 6: "Saturday"
    },
    "weathersit": {
        1: "Clear",
        2: "Mist/Cloudy",
        3: "Light Rain/Snow",
        4: "Heavy Rain/Snow"
    }
}, inplace=True)

# Urutan kategori
month_order = ["Jan", "Feb", "Mar", "Apr", "May", "Jun",
               "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"]

day_order = ["Sunday", "Monday", "Tuesday", "Wednesday",
             "Thursday", "Friday", "Saturday"]

season_order = ["Springer", "Summer", "Fall", "Winter"]

weather_order = ["Clear", "Mist/Cloudy", "Light Rain/Snow", "Heavy Rain/Snow"]

# Set sebagai categorical berurutan
df_day['mnth'] = pd.Categorical(df_day['mnth'], categories=month_order, ordered=True)
df_day['weekday'] = pd.Categorical(df_day['weekday'], categories=day_order, ordered=True)
df_day['season'] = pd.Categorical(df_day['season'], categories=season_order, ordered=True)
df_day['weathersit'] = pd.Categorical(df_day['weathersit'], categories=weather_order, ordered=True)

# Daftar kolom kategorikal
categorical_cols = ['season', 'yr', 'mnth', 'holiday', 'weekday', 'workingday', 'weathersit']

# Plot distribusi
for col in categorical_cols:
    plt.figure()
    ax = df_day[col].value_counts().sort_index().plot(kind='bar')

    # Tambahkan label di atas bar
    for p in ax.patches:
        ax.annotate(str(int(p.get_height())),
                    (p.get_x() + p.get_width() / 2, p.get_height()),
                    ha='center', va='bottom')

    plt.title(f'Distribusi {col}')
    plt.xlabel(col)
    plt.ylabel('Frekuensi')
    plt.show()

# %% [markdown]
# **Insight:**
# - Variabel temp dan atemp memiliki distribusi cenderung simetris
# - Variabel hum dan windspeed memiliki distribusi right skewed
# - Variabel hum memiliki 2 outlier bawah, sedangkan variabel windspeed memiliki beberapa outlier atas
# - Jumlah masing-masing kategori pada variabel season, yr, month, dan weekday cenderung sama, sedangkan jumlah masing-masing kategori pada variabel holiday, workingday, dan weathersit cenderung berbeda.

# %% [markdown]
# #### Data hour

# %%
data = df_hour[['temp', 'atemp', 'hum', 'windspeed']]
plt.figure()
plt.boxplot(data.values, labels=data.columns)
plt.title('Boxplot Variabel Cuaca')
plt.xlabel('Variabel')
plt.ylabel('Nilai')
plt.show()
# Out:
# /tmp/ipykernel_787/1018063436.py:3: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(data.values, labels=data.columns)

# %%
# Mapping label
df_hour.replace({
    "season": {1: "Springer", 2: "Summer", 3: "Fall", 4: "Winter"},
    "yr": {0: 2011, 1: 2012},
    "mnth": {
        1: "Jan", 2: "Feb", 3: "Mar", 4: "Apr",
        5: "May", 6: "Jun", 7: "Jul", 8: "Aug",
        9: "Sep", 10: "Oct", 11: "Nov", 12: "Dec"
    },
    "holiday": {0: "Not Holiday", 1: "Holiday"},
    "workingday": {0: "Holiday", 1: "Working Day"},
    "weekday": {
        0: "Sunday", 1: "Monday", 2: "Tuesday",
        3: "Wednesday", 4: "Thursday", 5: "Friday", 6: "Saturday"
    },
    "weathersit": {
        1: "Clear",
        2: "Mist/Cloudy",
        3: "Light Rain/Snow",
        4: "Heavy Rain/Snow"
    }
}, inplace=True)

# Urutan kategori
month_order = ["Jan", "Feb", "Mar", "Apr", "May", "Jun",
               "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"]

day_order = ["Sunday", "Monday", "Tuesday", "Wednesday",
             "Thursday", "Friday", "Saturday"]

season_order = ["Springer", "Summer", "Fall", "Winter"]

weather_order = ["Clear", "Mist/Cloudy", "Light Rain/Snow", "Heavy Rain/Snow"]

# Set sebagai categorical berurutan
df_hour['mnth'] = pd.Categorical(df_hour['mnth'], categories=month_order, ordered=True)
df_hour['weekday'] = pd.Categorical(df_hour['weekday'], categories=day_order, ordered=True)
df_hour['season'] = pd.Categorical(df_hour['season'], categories=season_order, ordered=True)
df_hour['weathersit'] = pd.Categorical(df_hour['weathersit'], categories=weather_order, ordered=True)

# Daftar kolom kategorikal
categorical_cols = ['season', 'yr', 'mnth', 'holiday', 'weekday', 'workingday', 'weathersit']

# Plot distribusi
for col in categorical_cols:
    plt.figure()
    ax = df_hour[col].value_counts().sort_index().plot(kind='bar')

    # Tambahkan label di atas bar
    for p in ax.patches:
        ax.annotate(str(int(p.get_height())),
                    (p.get_x() + p.get_width() / 2, p.get_height()),
                    ha='center', va='bottom')

    plt.title(f'Distribusi {col}')
    plt.xlabel(col)
    plt.ylabel('Frekuensi')
    plt.show()

# %% [markdown]
# **Insight:**
# - Variabel temp dan atemp memiliki distribusi cenderung simetris
# - Variabel hum dan windspeed memiliki distribusi right skewed
# - Variabel hum memiliki 2 outlier bawah, sedangkan variabel windspeed memiliki beberapa outlier atas
# - Jumlah masing-masing kategori pada variabel season, yr, month, dan weekday cenderung sama, sedangkan jumlah masing-masing kategori pada variabel holiday, workingday, dan weathersit cenderung berbeda.

# %% [markdown]
# ### Explore Matriks Korelasi

# %%
numeric_cols = ['yr', 'holiday', 'workingday',
                'temp', 'atemp', 'hum', 'windspeed',
                'casual', 'registered', 'cnt']
corr = df_day[numeric_cols].corr(method='pearson')
plt.figure()
plt.imshow(corr)
plt.colorbar()

for i in range(len(corr.columns)):
    for j in range(len(corr.columns)):
        plt.text(j, i, round(corr.iloc[i, j], 2),
                 ha='center', va='center')

plt.xticks(range(len(corr.columns)), corr.columns, rotation=90)
plt.yticks(range(len(corr.columns)), corr.columns)

plt.title('Matriks Korelasi Pearson')
plt.show()

# %% [markdown]
# **Insight:**
# - Variabel registered memiliki korelasi sangat kuat terhadap cnt. Artinya, total penyewaan sepeda didominasi oleh pengguna terdaftar dibandingkan casual.
# - Variabel temp memiliki korelasi sangat kuat terhadap atemp sehingga bisa digunakan salah satu saja.
# - Variabel hum dan windspeed memiliki korelasi negatif terhadap cnt. Artinya, semakin lembap atau berangin, jumlah penyewaan cenderung menurun.

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### Pertanyaan 1: Seberapa besar pengaruh variabel terhadap jumlah penyewaan sepeda selama tahun 2012

# %%
df_2012 = df_day[df_day['yr'] == 2012]
plt.figure(figsize=(7,5))
sns.regplot(data=df_2012, x='temp', y='cnt', scatter_kws={'alpha':0.5})
plt.title('Pengaruh Temperatur terhadap Penyewaan Sepeda (2012)')
plt.xlabel('Temperature')
plt.ylabel('Jumlah Penyewaan (cnt)')
plt.show()

# %%
plt.figure(figsize=(7,5))
sns.regplot(data=df_2012, x='atemp', y='cnt', scatter_kws={'alpha':0.5}, color='blue')
plt.title('Pengaruh Temperatur terhadap Penyewaan Sepeda (2012)')
plt.xlabel('Temperature')
plt.ylabel('Jumlah Penyewaan (cnt)')
plt.show()

# %%
plt.figure(figsize=(7,5))
sns.regplot(data=df_2012, x='hum', y='cnt', scatter_kws={'alpha':0.5}, color='green')
plt.title('Pengaruh Kelembapan terhadap Penyewaan Sepeda (2012)')
plt.xlabel('Humidity')
plt.ylabel('Jumlah Penyewaan (cnt)')
plt.show()

# %%
plt.figure(figsize=(7,5))
sns.regplot(data=df_2012, x='windspeed', y='cnt', scatter_kws={'alpha':0.5}, color='red')
plt.title('Pengaruh Kecepatan Angin terhadap Penyewaan Sepeda (2012)')
plt.xlabel('Windspeed')
plt.ylabel('Jumlah Penyewaan (cnt)')
plt.show()

# %% [markdown]
# **Insight:**
# - Temperatur memiliki pengaruh yang positif terhadap penyewaan sepeda. Seiring dengan peningkatan suhu, jumlah penyewaan sepeda cenderung meningkat secara linier.

# %% [markdown]
# ### Pertanyaan 2: Berapa rata-rata jumlah penyewaan sepeda pada hari kerja dibandingkan akhir pekan dalam setiap musim selama periode 2011-2012?

# %%
df_day['day_type'] = df_day['workingday'].replace({'Holiday': 'Weekend/Holiday'})

grouped = df_day.groupby(['season', 'day_type'], observed=False)['cnt'].mean().unstack()

# Plot
ax = grouped.plot(kind='bar', colormap='coolwarm')
plt.ylim(0, grouped.values.max() * 1.1)

for p in ax.patches:
    height = p.get_height()
    ax.annotate(f'{height:.0f}',
                (p.get_x() + p.get_width() / 2, height),
                ha='center', va='bottom',
                xytext=(0, 3),
                textcoords='offset points')

ax.legend(fontsize=8, title_fontsize=9)

plt.title('Rata-rata Penyewaan: Working Day vs Weekend per Season')
plt.xlabel('Season')
plt.ylabel('Rata-rata cnt')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# **Insight:**
# - Pada musim semi (Springer), gugur (Fall), dan dingin (Winter), rata-rata penyewaan sepeda pada hari kerja lebih tinggi dibandingkan akhir pekan/hari libur.
# - Pada musim panas (Summer), rata-rata penyewaan sepeda pada akhir pekan/hari libur sedikit lebih tinggi dibandingkan hari kerja.
# - Musim gugur (Fall) memiliki rata-rata penyewaan sepeda tertinggi secara keseluruhan, baik pada hari kerja maupun akhir pekan/hari libur. Hal ini musim ini adalah yang paling sering untuk penyewaan sepeda.

# %% [markdown]
# ### Pertanyaan 3: Pada bulan apa tingkat penyewaan sepeda tertinggi di tahun 2011?

# %%
# Filter tahun 2011
df_2011 = df_day[df_day['yr'] == 2011]

monthly_avg = df_2011.groupby('mnth')['cnt'].mean()

peak_month = monthly_avg.idxmax()

# Plot line chart
plt.figure(figsize=(8,5))
plt.plot(monthly_avg.index, monthly_avg.values, marker='o')

plt.scatter(peak_month, monthly_avg.loc[peak_month], s=100)
plt.text(peak_month, monthly_avg.loc[peak_month] + 50,
         f'{monthly_avg.loc[peak_month]:.0f}',
         ha='center', va='bottom', fontsize=9)

plt.title('Rata-rata Penyewaan Sepeda per Bulan (2011)')
plt.xlabel('Bulan (1–12)')
plt.ylabel('Rata-rata cnt')
plt.xticks(monthly_avg.index)

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_787/3058928093.py:4: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   monthly_avg = df_2011.groupby('mnth')['cnt'].mean()

# %% [markdown]
# **Insight:**
# - Rata-rata penyewaan sepeda tertinggi pada tahun 2011 terjadi pada bulan Juni sekitar 4784.

# %% [markdown]
# ### Pertanyaan 4: Pada jam berapa tingkat penyewaan sepeda tertinggi terjadi setiap bulan di tahun 2011 dan 2012?

# %%
# Filter tahun 2011 & 2012
df_hour_2yr = df_hour[df_hour['yr'].isin([2011, 2012])].copy()

grouped = df_hour_2yr.groupby(['yr', 'mnth', 'hr'])['cnt'].mean().reset_index()

peak_hour = grouped.loc[grouped.groupby(['yr', 'mnth'])['cnt'].idxmax()]

# Plot
plt.figure(figsize=(10,6))

for year in [2011, 2012]:
    data = peak_hour[peak_hour['yr'] == year]

    plt.plot(data['mnth'], data['hr'], marker='o', label=str(year))

    for i in range(len(data)):
        x = data['mnth'].iloc[i]
        y = data['hr'].iloc[i]
        plt.text(x, y + 0.3, f'{int(y)}', ha='center', fontsize=8)

plt.title('Jam Puncak Penyewaan Sepeda per Bulan (2011 vs 2012)')
plt.xlabel('Bulan (1–12)')
plt.ylabel('Jam Puncak')
plt.xticks(range(1,13))
plt.yticks(range(0,24))
plt.legend(title='Tahun')

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_787/3527190489.py:5: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = df_hour_2yr.groupby(['yr', 'mnth', 'hr'])['cnt'].mean().reset_index()
# /tmp/ipykernel_787/3527190489.py:8: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   peak_hour = grouped.loc[grouped.groupby(['yr', 'mnth'])['cnt'].idxmax()]

# %% [markdown]
# **Insight:**
# - Jam 17:00 (5 sore) merupakan waktu puncak penyewaan sepeda tertinggi di setiap bulan selama tahun 2011 dan 2012.

# %% [markdown]
# ### Pertanyaan 5: Berapa proporsi pengguna casual dibandingkan registered dalam total penyewaan sepeda setiap musim selama tahun 2011-2012?

# %%
grouped = df_day.groupby('season')[['casual', 'registered']].sum()

prop = grouped.div(grouped.sum(axis=1), axis=0)

# Plot
ax = prop.plot(kind='bar', stacked=True, colormap='coolwarm', figsize=(8,5))

for container in ax.containers:
    ax.bar_label(container, fmt='%.1f', label_type='center', fontsize=15)

ax.legend(title='User Type', fontsize=8, title_fontsize=9, loc='upper right')

plt.title('Proporsi Casual vs Registered per Season')
plt.xlabel('Season')
plt.ylabel('Proporsi')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_787/1741058889.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = df_day.groupby('season')[['casual', 'registered']].sum()

# %% [markdown]
# **Insight:**
# - Pengguna terdaftar mendominasi total penyewaan sepeda di semua musim.
# - Proporsi pengguna casual relatif lebih tinggi pada musim panas (Summer) dan gugur (Fall)
# - Pada musim semi (Springer) dan dingin (Winter), proporsi pengguna casual lebih rendah.

# %% [markdown]
# ### Pertanyaan 6: Seberapa besar penurunan rata-rata jumlah penyewaan sepeda pada kondisi cuaca buruk (weathersit = 3 dan 4) dibandingkan cuaca cerah (weathersit = 1) dalam periode 2011-2012?

# %%
df_weather = df_day[df_day['yr'].isin([2011, 2012])]

avg_weather = df_weather.groupby('weathersit')['cnt'].mean()

clear = avg_weather.loc['Clear']
bad = avg_weather.loc[['Light Rain/Snow', 'Heavy Rain/Snow']].mean()

drop = clear - bad
drop_pct = (drop / clear) * 100

comparison = pd.DataFrame({
    'Kategori': ['Cerah (1)', 'Buruk (3-4)'],
    'Rata-rata': [clear, bad]
})

# Plot
plt.figure(figsize=(7,5))
bars = plt.bar(comparison['Kategori'], comparison['Rata-rata'])

for bar in bars:
    y = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, y,
             f'{y:.0f}', ha='center', va='bottom', fontsize=9)

plt.title(f'Penurunan Penyewaan pada Cuaca')

plt.ylabel('Rata-rata cnt')
plt.tight_layout()
plt.show()

print(f"Penurunan: {drop:.2f} ({drop_pct:.2f}%)")
# Out:
# /tmp/ipykernel_787/2956230177.py:5: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   avg_weather = df_weather.groupby('weathersit')['cnt'].mean()
# Penurunan: 3073.50 (63.02%)

# %% [markdown]
# **Insight:**
# - Rata-rata jumlah penyewaan sepeda mengalami penurunan signifikan pada kondisi cuaca buruk dibandingkan dengan kondisi cuaca cerah

# %% [markdown]
# ## Analisis Lanjutan (RFM)

# %%
threshold = df_day['cnt'].median()

df_day['high_activity'] = df_day['cnt'] > threshold

# Tentukan tanggal referensi (tanggal terakhir di dataset)
ref_date = df_day['dteday'].max()

# Hitung RFM
rfm = df_day.groupby('season').agg({
    'dteday': lambda x: (ref_date - x.max()).days,   # Recency
    'high_activity': 'sum',                         # Frequency
    'cnt': 'sum'                                    # Monetary
}).reset_index()

rfm.columns = ['season', 'Recency', 'Frequency', 'Monetary']

print(rfm)

sns.pairplot(rfm[['Recency','Frequency','Monetary']])
plt.show()
# Out:
# /tmp/ipykernel_787/32922352.py:9: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   rfm = df_day.groupby('season').agg({
#      season  Recency  Frequency  Monetary
# 0  Springer        0         16    471348
# 1    Summer      194        113    918589
# 2      Fall      100        143   1061129
# 3    Winter       11         93    841613

# %% [markdown]
# **Insight:**
# - Fall (Musim Gugur): kinerja terbaik dengan frekuensi aktivitas tinggi dan total penyewaan tertinggi.
# - Summer (Musim Panas): kinerja yang kuat dalam hal frekuensi dan total penyewaan meskipun aktivitas terakhir terjadi paling lama dibandingkan musim lainnya.
# - Winter (Musim Dingin): kinerja cukup baik dengan recency yang relatif baru.
# - Springer (Musim Semi): kinerja terendah, tetapi recency 0 hari menunjukkan aktivitas terkini dalam dataset ini.

# %% [markdown]
# ## Conclusion & Recommendation

# %% [markdown]
# - **Conclusion pertanyaan 1:** Suhu (temp) memiliki pengaruh positif dan signifikan terhadap jumlah penyewaan sepeda selama tahun 2012. Seiring dengan peningkatan suhu, jumlah penyewaan sepeda cenderung meningkat secara linier, menunjukkan bahwa cuaca yang lebih hangat mendorong lebih banyak orang untuk menyewa sepeda.
# - **Conclusion pertanyaan 2:**  Pada musim gugur (Fall), rata-rata penyewaan sepeda adalah yang tertinggi secara keseluruhan, baik pada hari kerja maupun akhir pekan/hari libur. Pada musim semi (Springer), gugur (Fall), dan dingin (Winter), rata-rata penyewaan sepeda pada hari kerja lebih tinggi dibandingkan akhir pekan/hari libur. Namun, pada musim panas (Summer), rata-rata penyewaan sepeda pada akhir pekan/hari libur sedikit lebih tinggi dibandingkan hari kerja.
# - **Conclusion pertanyaan 3:** Bulan Juni 2011 memiliki tingkat penyewaan sepeda tertinggi, sedangkan bulan Januari 2011 memiliki tingkat penyewaan sepeda terendah.
# - **Conclusion pertanyaan 4:**
# Jam 17:00 (5 sore) merupakan waktu puncak penyewaan sepeda tertinggi di setiap bulan selama tahun 2012. Tingkat penyewaan pada jam ini secara signifikan lebih tinggi dibandingkan jam-jam lainnya.
# - **Conclusion pertanyaan 5:** Pengguna terdaftar mendominasi total penyewaan sepeda di semua musim. Proporsi pengguna casual relatif lebih tinggi pada musim panas (Summer) dan gugur (Fall). Sementara itu, pada musim semi (Springer) dan dingin (Winter), proporsi pengguna casual lebih rendah.
# - **Conclusion pertanyaan 6:** Rata-rata jumlah penyewaan sepeda mengalami penurunan signifikan pada kondisi cuaca buruk dibandingkan dengan kondisi cuaca cerah. Hal ini menunjukkan penurunan sebesar kurang lebih 63% pada kondisi cuaca buruk dibandingkan cuaca cerah.

# %% [markdown]
# **Rekomendasi Action Item:**
# - **Optimalkan Ketersediaan Sepeda**: Sesuaikan jumlah sepeda yang tersedia berdasarkan pola permintaan musiman yang teridentifikasi, terutama peningkatan di musim gugur (Fall).
# - **Strategi Pemasaran Bertarget**: Fokuskan kampanye pemasaran pada pengguna casual, terutama di musim panas (Summer) dan gugur (Fall) ketika proporsi mereka lebih tinggi. Tawarkan promo khusus atau program keanggotaan singkat untuk menarik lebih banyak pengguna casual.
# - **Mitigasi Dampak Cuaca Buruk**: Pertimbangkan untuk menawarkan promosi atau diskon khusus pada hari-hari dengan perkiraan cuaca buruk untuk mendorong penggunaan sepeda, atau menyediakan fasilitas alternatif seperti payung atau jas hujan di stasiun penyewaan.
# - **Pemeliharaan dan Infrastruktur**: Lakukan pemeliharaan dan inspeksi rutin terhadap sepeda dan infrastruktur agar tetap optimal, terutama saat kondisi cuaca ekstrem. Pastikan jalur sepeda aman dan dapat diakses dalam berbagai kondisi cuaca.
# - **Analisis Waktu Puncak Harian**: Manfaatkan data jam puncak (terutama jam 17:00) untuk memastikan ketersediaan sepeda yang maksimal dan memadai di lokasi-lokasi strategis. Pertimbangkan untuk menawarkan insentif pengembalian sepeda di luar jam puncak untuk menyeimbangkan distribusi.

# %%
# Menyimpan dataframe yang sudah bersih ke file CSV
df_day.to_csv('day_clean.csv', index=False)
df_hour.to_csv('hour_clean.csv', index=False)
